# %%
import pandas as pd

# %%
#READ CSV FILE HERE
df=pd.read_csv("SAMPLEIDS (1).csv")
df=pd.DataFrame(df)
df
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM   NaN  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0   NaN   NaN
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
#DISPLAY THE INFORMATION ABOUT CSV AND RUN THE BASIC DATA ANALYSIS FUNCTIONS
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SNO      21 non-null     int64
#  1   REGNO    21 non-null     int64
#  2   NAME     20 non-null     object
#  3   DOB      21 non-null     object
#  4   GENDER   20 non-null     object
#  5   ADDRESS  20 non-null     object
#  6   M1       18 non-null     float64
#  7   M2       19 non-null     float64
#  8   M3       17 non-null     float64
#  9   M4       18 non-null     float64
#  10  TOTAL    16 non-null     float64
#  11  AVG      20 non-null     float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 2.1+ KB

# %%
#CHECK OUT NULL VALUES IN DATA SET USING FUNCTION
df.isnull()
# Out:
#       SNO  REGNO   NAME    DOB  GENDER  ADDRESS     M1     M2     M3     M4  \
# 0   False  False  False  False   False    False  False  False  False   True
# 1   False  False  False  False   False    False  False  False  False  False
# 2   False  False  False  False   False    False   True  False  False  False
# 3   False  False  False  False   False    False  False  False  False  False
# 4   False  False  False  False   False    False  False  False  False  False
# 5   False  False  False  False   False    False  False  False  False  False
# 6   False  False  False  False   False    False  False  False  False  False
# 7   False  False  False  False   False    False  False  False  False  False
# 8   False  False  False  False   False    False  False  False  False  False
# 9   False  False  False  False   False    False  False   True   True  False
# 10  False  False  False  False   False    False  False  False  False  False
# ...

# %%
#DISPLAY THE SUM ON NULL VALUES IN EACH ROWS
df.isnull().sum()
# Out:
# SNO        0
# REGNO      0
# NAME       1
# DOB        0
# GENDER     1
# ADDRESS    1
# M1         3
# M2         2
# M3         4
# M4         3
# TOTAL      5
# AVG        1
# dtype: int64

# %%
#DROP NULL VALUES(ANY)
df.dropna(how='any')
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# 11   11  1220131      KANI  2000-11-21  FEMALE      CHITHUR  96.0  95.0  96.0
# 14   14  1220134      NANI    20001109    MALE   POONAMALEE  79.0  77.0  80.0
# 16   16  1220136   PRATHAP    20000921    MALE  KANCHIPURAM  86.0  84.0  90.0
# ...

# %%
## DROP NULL VALUES WITH THE SPECIFIC ROWS(ANY)
df_any_row = df.dropna(axis=0, how='any')
df_any_row
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# 11   11  1220131      KANI  2000-11-21  FEMALE      CHITHUR  96.0  95.0  96.0
# 14   14  1220134      NANI    20001109    MALE   POONAMALEE  79.0  77.0  80.0
# 16   16  1220136   PRATHAP    20000921    MALE  KANCHIPURAM  86.0  84.0  90.0
# ...

# %%
# DROP NULL VALUES WITH THE SPECIFIC COLUMN(ANY)

df_any_column = df.dropna(axis=1, how='any')
df_any_column
# Out:
#     SNO    REGNO         DOB
# 0     1  1220121  2000-02-10
# 1     2  1220122  1999-01-25
# 2     3  1220123  2000.09.21
# 3     4  1220124  2000-11-09
# 4     5  1220125  2000-11-21
# 5     6  1220126  1999-03-05
# 6     7  1220127  2000-10-02
# 7     7  1220127  2000-10-02
# 8     8  1220128  1999-01-25
# 9     9  1220129  2000.09.21
# 10   10  1220130  2000-11-09
# 11   11  1220131  2000-11-21
# 12   12  1220132  1999-03-05
# 13   13  1220133  2000-10-02
# 14   14  1220134    20001109
# 15   15  1220135    19990125
# 16   16  1220136    20000921
# 17   17  1220137    20001109
# 18   18  1220138    20001121
# 19   19  1220139    19990305
# 20   20  1220140    20001002

# %%
## DROP NULL VALUES(ALL)
df.dropna(how='all')
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM   NaN  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0   NaN   NaN
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
# DROP NULL VALUES WITH SPECIFIC ROWS(ALL)

df_any_ROW = df.dropna(axis=0, how='all')
df_any_ROW
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM   NaN  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0   NaN   NaN
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
# DROP NULL VALUES WITH SPECIFIC COLUMN(ALL)

df_any_COLUMN = df.dropna(axis=1, how='all')
df_any_COLUMN
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM   NaN  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0   NaN   NaN
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
# Drop rows with less than 3 non-null values
df_thresh = df.dropna(thresh=2)
df_thresh
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM   NaN  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0   NaN   NaN
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
# Drop rows based on subset of columns
df_subset = df.dropna(subset=['SNO', 'DOB'])
df_subset
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM   NaN  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0   NaN   NaN
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
import pandas as pd
import seaborn as sns
sns.heatmap(df.isnull(),yticklabels=False,annot=True)
# Out:
# <Axes: >

# %%
#FILL NULL VALUES WITH CONSTANT VALUE "O"
df_filled = df.fillna("O")

df_filled
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM     O  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0     O     O
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
#FILL NULL VALUES WITH ffill or bfill METHOD

# Forward Fill (ffill)
df_ffill = df.fillna(method='ffill')
df_ffill
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM  56.0  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0  96.0  90.0
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
# BACKFILL FILL WITH NULL VALUES
df_bfill = df.fillna(method='bfill')
df_bfill
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS    M1    M2    M3  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.0  81.0  90.0
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.0  61.0  80.0
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM  74.0  59.0  60.0
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.0  79.0  80.0
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.0  95.0  96.0
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.0  88.0  90.0
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.0  51.0  70.0
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.0  96.0  90.0
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.0  45.0  50.0
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.0  45.0  50.0
# ...

# %%
#CALCULATE MEAN VALUE OF A TOTAL COLUMN AND FILL IT WITH NULL VALUES
mn=df.mean()
print(mn)

df.fillna(mn,inplace=True)
print(df)
# Out:
# SNO      1.033333e+01
# REGNO    1.220130e+06
# M1       7.366667e+01
# M2       7.431579e+01
# M3       7.952941e+01
# M4       7.316667e+01
# TOTAL    2.727500e+02
# AVG      7.273333e+01
# dtype: float64
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS         M1  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.000000
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.000000
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM  73.666667
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.000000
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.000000
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.000000
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.000000
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.000000
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.000000
# ...

# %%
## M1 COLUMN FILL WITH MEAN VALUES

mn=df.M1.mean()
print(mn)

df['M1'].fillna(mn,inplace=True)
print(df['M1'])
# Out:
# 73.66666666666667
# 0     82.000000
# 1     56.000000
# 2     73.666667
# 3     74.000000
# 4     92.000000
# 5     91.000000
# 6     49.000000
# 7     49.000000
# 8     95.000000
# 9     64.000000
# 10    34.000000
# 11    96.000000
# 12    73.666667
# 13    71.000000
# 14    79.000000
# 15    73.666667
# 16    86.000000
# 17    67.000000
# 18    81.000000
# 19    84.000000
# 20    76.000000
# Name: M1, dtype: float64

# %%
## M2 COLUMN FILL WITH MEAN VALUES

mn=df.M2.mean()
print(mn)

df['M2'].fillna(mn,inplace=True)
print(df['M2'])
# Out:
# 74.3157894736842
# 0     81.000000
# 1     61.000000
# 2     59.000000
# 3     79.000000
# 4     95.000000
# 5     88.000000
# 6     51.000000
# 7     51.000000
# 8     96.000000
# 9     74.315789
# 10    45.000000
# 11    95.000000
# 12    68.000000
# 13    76.000000
# 14    77.000000
# 15    74.315789
# 16    84.000000
# 17    64.000000
# 18    86.000000
# 19    87.000000
# 20    69.000000
# Name: M2, dtype: float64

# %%
## M3 COLUMN FILL WITH MEAN VALUES

mn=df.M3.mean()
print(mn)

df['M3'].fillna(mn,inplace=True)
print(df['M3'])
# Out:
# 79.52941176470588
# 0     90.000000
# 1     80.000000
# 2     60.000000
# 3     80.000000
# 4     96.000000
# 5     90.000000
# 6     70.000000
# 7     70.000000
# 8     90.000000
# 9     79.529412
# 10    50.000000
# 11    96.000000
# 12    70.000000
# 13    79.529412
# 14    80.000000
# 15    79.529412
# 16    90.000000
# 17    70.000000
# 18    90.000000
# 19    79.529412
# 20    80.000000
# Name: M3, dtype: float64

# %%
## M4 COLUMN FORWARD FILL WITH MEAN VALUES

mn=df.M4.mean()
print(mn)

df['M4'].fillna(mn,inplace=True)
print(df['M4'])
# Out:
# 73.16666666666667
# 0     73.166667
# 1     56.000000
# 2     70.000000
# 3     74.000000
# 4     92.000000
# 5     91.000000
# 6     49.000000
# 7     49.000000
# 8     95.000000
# 9     64.000000
# 10    34.000000
# 11    96.000000
# 12    70.000000
# 13    71.000000
# 14    79.000000
# 15    73.166667
# 16    86.000000
# 17    73.166667
# 18    81.000000
# 19    84.000000
# 20    76.000000
# Name: M4, dtype: float64

# %%
## AVG COLUMN FILL WITH MEAN VALUES

mn=df.AVG.mean()
print(mn)

df['AVG'].fillna(mn,inplace=True)
print(df['AVG'])
# Out:
# 72.7333333295
# 0      72.733333
# 1      84.333333
# 2       0.000000
# 3     102.333333
# 4     125.000000
# 5     120.000000
# 6      73.000000
# 7      73.000000
# 8     125.333333
# 9       0.000000
# 10     54.333333
# 11    127.666667
# 12     69.333333
# 13      0.000000
# 14    105.000000
# 15      0.000000
# 16    115.333333
# 17     67.000000
# 18    112.666667
# 19      0.000000
# 20    100.333333
# Name: AVG, dtype: float64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %%
## MODIFIED DATAFRAME WITH MEAN VALES OF ALL NUMBERICAL COLUMNS
df
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS         M1  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.000000
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.000000
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM  73.666667
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.000000
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.000000
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.000000
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.000000
# 7     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.000000
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.000000
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.000000
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.000000
# 11   11  1220131      KANI  2000-11-21  FEMALE      CHITHUR  96.000000
# ...

# %%
## DROP DUPLICATES 
df.drop_duplicates(inplace=True)
df
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS         M1  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.000000
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.000000
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM  73.666667
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.000000
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.000000
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.000000
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.000000
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.000000
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.000000
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.000000
# 11   11  1220131      KANI  2000-11-21  FEMALE      CHITHUR  96.000000
# 12   12  1220132  LATHESSH  1999-03-05    MALE    THANDALAM  73.666667
# ...

# %%
## DROP THE NULL VALUES AND PERMANTLY REMOVED THE SPECIFIC ROW

df.dropna(axis=0,how='any',inplace=True)
df
# Out:
#     SNO    REGNO      NAME         DOB  GENDER      ADDRESS         M1  \
# 0     1  1220121      ARUN  2000-02-10    MALE    THANDALAM  82.000000
# 1     2  1220122      BABU  1999-01-25    MALE  KANCHIPURAM  56.000000
# 2     3  1220123    CHARAN  2000.09.21    MALE    THANDALAM  73.666667
# 3     4  1220124      DEVA  2000-11-09    MALE   POONAMALEE  74.000000
# 4     5  1220125     ESTER  2000-11-21  FEMALE      CHITHUR  92.000000
# 5     6  1220126   FARHANA  1999-03-05  FEMALE    THANDALAM  91.000000
# 6     7  1220127      GANI  2000-10-02    MALE  KANCHIPURAM  49.000000
# 8     8  1220128      HEMA  1999-01-25  FEMALE   POONAMALEE  95.000000
# 9     9  1220129     INDRA  2000.09.21  FEMALE  KANCHIPURAM  64.000000
# 10   10  1220130    JAHITH  2000-11-09    MALE    THANDALAM  34.000000
# 11   11  1220131      KANI  2000-11-21  FEMALE      CHITHUR  96.000000
# 12   12  1220132  LATHESSH  1999-03-05    MALE    THANDALAM  73.666667
# ...

# %%
## IT SHOWS THE DUPLICATED VALUES IN THE OVERALL DATAFRAME
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %%
## PRINT THE COLUMN OF DOB
df['DOB']
# Out:
# 0     2000-02-10
# 1     1999-01-25
# 2     2000.09.21
# 3     2000-11-09
# 4     2000-11-21
# 5     1999-03-05
# 6     2000-10-02
# 8     1999-01-25
# 9     2000.09.21
# 10    2000-11-09
# 11    2000-11-21
# 12    1999-03-05
# 13    2000-10-02
# 14      20001109
# 16      20000921
# 17      20001109
# 18      20001121
# 19      19990305
# 20      20001002
# Name: DOB, dtype: object

# %%
## TO PRINT THE DATE OF YOUR GIVEN FORMAT
x=df['DOB'] = pd.to_datetime(df['DOB'], format=('%Y-%m-%d'))
x
# Out:
# 0    2000-02-10
# 1    1999-01-25
# 2    2000-09-21
# 3    2000-11-09
# 4    2000-11-21
# 5    1999-03-05
# 6    2000-10-02
# 8    1999-01-25
# 9    2000-09-21
# 10   2000-11-09
# 11   2000-11-21
# 12   1999-03-05
# 13   2000-10-02
# 14   2000-11-09
# 16   2000-09-21
# 17   2000-11-09
# 18   2000-11-21
# 19   1999-03-05
# 20   2000-10-02
# Name: DOB, dtype: datetime64[ns]

# %%
## Create a heatmap to visualize missing values
import pandas as pd
import seaborn as sns
sns.heatmap(df.isnull(),yticklabels=False,annot=True)
# Out:
# <Axes: >

# %%
## IQR
import pandas as pd
import seaborn as sns
import numpy as np

age=[1,3,28,27,25,92,30,39,40,50,26,24,29,94]
af=pd.DataFrame(age)
af
# Out:
#      0
# 0    1
# 1    3
# 2   28
# 3   27
# 4   25
# 5   92
# 6   30
# 7   39
# 8   40
# 9   50
# 10  26
# 11  24
# 12  29
# 13  94

# %%
#USE BOXPLOT FUNCTION HERE TO DETECT OUTLIER
sns.boxplot(data=af)
# Out:
# <Axes: >

# %%
# USE SCATTERPLOT FUNCTION HERE TO DETECT OUTLIER
sns.scatterplot(data=af)
# Out:
# <Axes: >

# %%
## IQR METHOD TO FIND THE OUTLIERS VALUES:
q1=np.quantile(age,0.25)
q2=np.quantile(age,0.50)
q3=np.quantile(age,0.75)
iqr=q3-q1
print("IQR:",iqr)
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr
print("LOWER BOUND:",lower_bound)
print("UPPER BOUND:",upper_bound)

outliers=[x for x in age if x < lower_bound or x > upper_bound]

print("Q1:",q1)
print("Q2:",q2)
print("Q3:",q3)
print("IQR:",iqr)
print("Lower Bound:",lower_bound)
print("Upper Bound:",upper_bound)
print("Outliers:",outliers)
# Out:
# IQR: 14.5
# LOWER BOUND: 3.5
# UPPER BOUND: 61.5
# Q1: 25.25
# Q2: 28.5
# Q3: 39.75
# IQR: 14.5
# Lower Bound: 3.5
# Upper Bound: 61.5
# Outliers: [1, 3, 92, 94]

# %%
## TO PRINT THE NEAREST VALUES AND OTHERS GIVES NULL VALUES
af=af[((af>=lower_bound)&(af<=upper_bound))]
af
# Out:
#        0
# 0    NaN
# 1    NaN
# 2   28.0
# 3   27.0
# 4   25.0
# 5    NaN
# 6   30.0
# 7   39.0
# 8   40.0
# 9   50.0
# 10  26.0
# 11  24.0
# 12  29.0
# 13   NaN

# %%
#REMOVE OUTLIERS
af.dropna()
# Out:
#        0
# 2   28.0
# 3   27.0
# 4   25.0
# 6   30.0
# 7   39.0
# 8   40.0
# 9   50.0
# 10  26.0
# 11  24.0
# 12  29.0

# %%
#USE BOXPLOT FUNCTION HERE TO CHECK OUTLIER IS REMOVED
sns.boxplot(data=af)
# Out:
# <Axes: >

# %%
## USE SCATTERPLOT FUNCTION HERE TO CHECK OUTLIER IS REMOVED
sns.scatterplot(data=af)
# Out:
# <Axes: >

# %%
from scipy import stats #STATS METHOD IS USED TO IMPLEMENT Z SCORE METHOD
import numpy as np
import matplotlib.pyplot as plt

# %%
data=[1,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,84,87,90,93,96,99,158]
data1=pd.DataFrame(data)
mean=np.mean(data)
std=np.std(data)
print("Mean of the dataset is",mean)
print("Std. deviation is",std)
# Out:
# Mean of the dataset is 57.0
# Std. deviation is 32.41913015489465

# %%
threshold=3
outlier=[]
z_scores=[]
for i in data:
    z = (i - mean) / std
    z_scores.append(z)
    if abs(z) > threshold:
        outlier.append(i)
print("Outlier in dataset is",outlier)
# Out:
# Outlier in dataset is [158]

# %%
## ANOTHER METHOD TO FIND THE Z-SCORE:
z=np.abs(stats.zscore(data1))
data1[data1>3]
# Out:
#         0
# 0     NaN
# 1    12.0
# 2    15.0
# 3    18.0
# 4    21.0
# 5    24.0
# 6    27.0
# 7    30.0
# 8    33.0
# 9    36.0
# 10   39.0
# 11   42.0
# 12   45.0
# 13   48.0
# 14   51.0
# 15   54.0
# 16   57.0
# 17   60.0
# 18   63.0
# 19   66.0
# 20   69.0
# 21   72.0
# 22   75.0
# 23   78.0
# 24   81.0
# 25   84.0
# 26   87.0
# 27   90.0
# 28   93.0
# 29   96.0
# 30   99.0
# 31  158.0

# %%
#USE BOXPLOT FUNCTION HERE TO DETECT OUTLIER
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
#USE SCATTERPLOT FUNCTION HERE TO DETECT OUTLIER
sns.scatterplot(data=data)
# Out:
# <Axes: >

# %%
## REMOVE THE OUTLIERS:
cleaned_data = [i for i in data if i not in outlier]
print("Data after removing outliers:", cleaned_data)
# Out:
# Data after removing outliers: [1, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]

# %%
## VISUALIZE ORIGINAL DATA WITH A BOXPLOT:
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.title('Boxplot of Original Data')
plt.show()

# %%
## VISUALIZE CLEANED DATA WITH A BOXPLOT:
plt.figure(figsize=(10, 6))
sns.boxplot(data=cleaned_data)
plt.title('Boxplot of Cleaned Data')
plt.show()
